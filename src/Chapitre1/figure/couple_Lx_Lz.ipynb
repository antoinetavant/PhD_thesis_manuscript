# %% [markdown]
# # New Notebook !

# %%
# Scientific libraries
import numpy as np
import scipy


# Graphic libraries

import matplotlib.pyplot as plt
# %matplotlib notebook


# Creating alias for magic commands

# LPPview Classes
from LPPview import *


data_succes = [  [ 0.25, 0.5,  0.5,  1], [ 1, 1,  0.5, 2]]
data_fail = [  [ 1, 2, 0.5 ], [ 1, 1, 0.3]]

plt.style.use("presentation")

plt.figure(figsize=(4,3))
plt.scatter(data_succes[0], data_succes[1],
            s=40, label='Physical')
plt.scatter(data_fail[0], data_fail[1], marker="^",
            s=40, label='Unphysical')

plt.legend(fontsize=12, loc="lower right")
plt.xlim(left=0)
plt.ylim(bottom=0)
#plt.title("")
plt.xlabel("Azimuthal length [cm]", fontsize=12)
plt.ylabel("Axial length [cm]", fontsize=12)

xvect = np.linspace(0,2,10)
yvect = 1.4*xvect-0.3

plt.plot(xvect, yvect, "k:", alpha=0.7)
plt.savefig("2D_couples.pdf")
# Out:
# <img src="data:image/png;base64,..." width="399.76666666666665">
