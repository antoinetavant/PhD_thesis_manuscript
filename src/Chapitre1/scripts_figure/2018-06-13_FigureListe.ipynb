# %%
# df
from IPython.core.display import HTML
HTML("""
<style>
.output_png {
    display: table-cell;
    text-align: center;
    vertical-align: middle;
}
</style>
""")
# Out:
# <style>
# .output_png {
#     display: table-cell;
#     text-align: center;
#     vertical-align: middle;
# }
# </style>

# %% [markdown]
# # List of the Figures
#
# There is a list of the figures.

# %% [markdown]
# # Figure 1
# The 2D shematic of the simulation

# %%
# %%capture
# %run 2D_shemat_and_snapshot.ipynb

# %%
fig = plot_schematic2D()

# %% [markdown]
# # Figure 2
# The SEE model

# %%
# %%capture
# %run SEE_models.ipynb

# %%
from functions import (maxwE)
plot_SEE_model()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-09aecdc408fa> in <module>
#       1 from functions import (maxwE)
# ----> 2 plot_SEE_model()
#
# NameError: name 'plot_SEE_model' is not defined

# %% [markdown]
# # figures 3 - 5
# the results

# %%
# %%capture
# %run Parametric_plots_17-04-2018.ipynb

# %%
plot_sig1()

# %%
plot_Te2()

plot_Te1()

# %%
plot_phi4()

# %%
plot_phi1()
plot_phi5()

# %%
plot_phi2()
plot_phi3()
