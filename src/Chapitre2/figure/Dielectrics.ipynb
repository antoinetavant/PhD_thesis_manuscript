# %% [markdown]
# # The plots for the Dielectrics !
#
# There is some stuffs from the dielectrics

# %%
# Scientific libraries
import numpy as np
import scipy


# Graphic libraries

import matplotlib.pyplot as plt
# %matplotlib notebook

plt.style.use("presentation")
plt.rcParams["figure.figsize"] = (4, 3)

# Creating alias for magic commands

# LPPview Classes
from LPPview import *
from LPPview.Classes.LPPic_temporal import History
from LPPview.Classes.LPPic_walls import walls as Walls
from LPPview.Classes.LPPic_newwalls import newwalls as Newwalls

root = "/home/tavant/Data/"
folders = ["test_65/","test_99/", "test_75/"]
names = ["nothing", "Diel and SEE", "No Diel SEE"]

paths = [root+f for f in folders]

# %% [markdown]
# # No SEE, only Dielectric effects

# %%
def plot_noSEE():
    
    for i in [0, 1]:
        

        path=paths[i]
        F = field(path)
        H = History(path)
        temporal_data = H.return_history()
        time = temporal_data["time"]*1e6
        # rate =  (temporal_data["elec_SEE"] +  temporal_data["elec_SEE_sup"])/ temporal_data["elec_wal"]
        # rate[0] = 0
        mob = temporal_data["mobi"]
        
        plt.figure()

        plt.plot(time, mob, label=names[i])
        
        
plot_noSEE()
# Out:
# found 1249 files
# found 1 files
# loading dat file
# <img src="data:image/png;base64,..." width="399.76666666666665">
# found 1251 files
# I've found a temporale file !
# found 1 files
# loading dat file
# <img src="data:image/png;base64,..." width="399.76666666666665">

# %% [markdown]
# # SEE and Dielectric effects

# %%
def plot_SEE_mobility():
    
    plt.figure()

    for i in [2, 1]:
        
        path=paths[i]
        print(path)
        F = field(path)
        H = History(path)
        temporal_data = H.return_history()
        time = temporal_data["time"]*1e6
        # rate =  (temporal_data["elec_SEE"] +  temporal_data["elec_SEE_sup"])/ temporal_data["elec_wal"]
        # rate[0] = 0
        mob = -temporal_data["mobi"]
        

        plt.plot(time, mob, label=names[i])
        
    plt.xlabel("Time [$\mu$s]", fontsize=11)
    plt.ylabel("Electron mobility $\mu_{\\rm PIC}$ [m$^2$ (s V)$^{-1}$]", fontsize=11)
    plt.xlim(left=0, right=10)
    
    plt.legend( fontsize=11)
    plt.tight_layout()
plot_SEE_mobility()

plt.savefig("dielectron_noSEE_mobility.pdf")
# Out:
# <img src="data:image/png;base64,..." width="399.76666666666665">
# /home/tavant/Data/test_75/
# found 1250 files
# I've found a temporale file !
# found 1 files
# loading dat file
# /home/tavant/Data/test_99/
# found 1251 files
# I've found a temporale file !
# found 1 files
# loading dat file
# /home/tavant/these/code/venv/stand/lib64/python3.7/site-packages/ipykernel_launcher.py:25: UserWarning: This figure was using constrained_layout==True, but that is incompatible with subplots_adjust and or tight_layout: setting constrained_layout==False.

# %%
def plot_SEE_mobility():
    
    plt.figure()
    
    labels = ["No dielectric", "With dielectric"]

    for i, n in zip([2, 1], labels):
        
        path=paths[i]
        print(path)
        F = field(path)
        H = History(path)
        temporal_data = H.return_history()
        time = temporal_data["time"]*1e6
        # rate =  (temporal_data["elec_SEE"] +  temporal_data["elec_SEE_sup"])/ temporal_data["elec_wal"]
        # rate[0] = 0
        mob = temporal_data["SUMe_x"]
        mob = temporal_data["mobi"]
        

        plt.plot(time, mob, label=n)
        
    plt.xlabel("Time [$\mu$s]", fontsize=11)
    plt.ylabel("Electron mobility $\mu_{\\rm PIC}$ [m$^2$ (s V)$^{-1}$]", fontsize=11)
    plt.xlim(left=0, right=10)
    
    plt.legend( fontsize=11)
    plt.tight_layout()
plot_SEE_mobility()

plt.savefig("dielectron_yesSEE_mobility.pdf")
# Out:
# <img src="data:image/png;base64,..." width="399.76666666666665">
# /home/tavant/Data/test_75/
# found 1250 files
# I've found a temporale file !
# found 1 files
# loading dat file
# /home/tavant/Data/test_99/
# found 1251 files
# I've found a temporale file !
# found 1 files
# loading dat file
# /home/tavant/these/code/venv/stand/lib64/python3.7/site-packages/ipykernel_launcher.py:28: UserWarning: This figure was using constrained_layout==True, but that is incompatible with subplots_adjust and or tight_layout: setting constrained_layout==False.

# %%
def plot_SEE_Ter():
    
    plt.figure()
    
    labels = ["No dielectric", "With dielectric"]

    for i, n in zip([2, 1], labels):
        
        path=paths[i]
        print(path)
        F = field(path)
        H = History(path)
        temporal_data = H.return_history()
        time = temporal_data["time"]*1e6
        # rate =  (temporal_data["elec_SEE"] +  temporal_data["elec_SEE_sup"])/ temporal_data["elec_wal"]
        # rate[0] = 0
        mob = temporal_data["SUMe_y"]
        

        plt.plot(time, mob, label=n)
        
    plt.xlabel("Time [$\mu$s]", fontsize=11)
    plt.ylabel("Radial electron Temperature T$_{e, R}$ [V]", fontsize=11)
    plt.xlim(left=0, right=10)
    
    plt.legend( fontsize=11)
    plt.tight_layout()
plot_SEE_Ter()

plt.savefig("dielectron_yesSEE_Ter.pdf")
# Out:
# <img src="data:image/png;base64,..." width="399.76666666666665">
# /home/tavant/Data/test_75/
# found 1250 files
# I've found a temporale file !
# found 1 files
# loading dat file
# /home/tavant/Data/test_99/
# found 1251 files
# I've found a temporale file !
# found 1 files
# loading dat file
# /home/tavant/these/code/venv/stand/lib64/python3.7/site-packages/ipykernel_launcher.py:27: UserWarning: This figure was using constrained_layout==True, but that is incompatible with subplots_adjust and or tight_layout: setting constrained_layout==False.

# %%
def plot_SEE_Ter():
    
    plt.figure()
    
    labels = ["No dielectric", "With dielectric"]

    for i, n in zip([2, 1], labels):
        
        path=paths[i]
        print(path)
        F = field(path)
        H = History(path)
        temporal_data = H.return_history()
        time = temporal_data["time"]*1e6
        # rate =  (temporal_data["elec_SEE"] +  temporal_data["elec_SEE_sup"])/ temporal_data["elec_wal"]
        # rate[0] = 0
        mob = temporal_data["SUMe_y"]
        

        plt.plot(time, mob, label=n)
        
    plt.xlabel("Time [$\mu$s]", fontsize=11)
    plt.ylabel("Radial electron Temperature T$_{e, R}$ [V]", fontsize=11)
    plt.xlim(left=0, right=10)
    
    plt.legend( fontsize=11)
    plt.tight_layout()
plot_SEE_Ter()

plt.savefig("dielectron_yesSEE_Ter.pdf")
# Out:
# <img src="data:image/png;base64,..." width="399.76666666666665">
# /home/tavant/Data/test_75/
# found 1250 files
# I've found a temporale file !
# found 1 files
# loading dat file
# /home/tavant/Data/test_99/
# found 1251 files
# I've found a temporale file !
# found 1 files
# loading dat file
# /home/tavant/these/code/venv/stand/lib64/python3.7/site-packages/ipykernel_launcher.py:27: UserWarning: This figure was using constrained_layout==True, but that is incompatible with subplots_adjust and or tight_layout: setting constrained_layout==False.

# %%
path=paths[0]
F = field(path)
F._path
F._ndiel=0
# Out:
# found 1249 files

# %%
tab_ne = F.meanfield(label="Nume", mean_axis="x", imin=0.2)
tab_ni = F.meanfield(label="Numi", mean_axis="x", imin=0.2)
tab_phi = F.meanfield(label="Phi", mean_axis="x", imin=0.2)
# Out:
# 1249
# calculating the mean between 1.99$ \mu s$  and 9.99$ \mu s$
# 1249
# calculating the mean between 1.99$ \mu s$  and 9.99$ \mu s$
# 1249
# calculating the mean between 1.99$ \mu s$  and 9.99$ \mu s$

# %%
plt.figure()
plt.plot(tab_ne)
plt.plot(tab_ni)

plt.figure()
plt.plot(tab_phi)
# Out:
# <img src="data:image/png;base64,..." width="400">
# <img src="data:image/png;base64,..." width="400">

# %%
def plot_SEE_rate():
    
    plt.figure()
    
    labels = ["No dielectric", "With dielectric"]

    for i, n in zip([2, 1], labels):
        
        path=paths[i]
        print(path)
        F = field(path)
        H = History(path)
        temporal_data = H.return_history()
        time = temporal_data["time"]*1e6
        rate =  (temporal_data["elec_SEE"] +  temporal_data["elec_SEE_sup"])/ temporal_data["elec_wal"]
        rate[0] = 0

        plt.plot(time, rate, label=n)
        
    plt.xlabel("Time [$\mu$s]", fontsize=11)
    plt.ylabel("Emission rate $\\bar{\\sigma}$", fontsize=11)
    plt.xlim(left=0, right=10)
    plt.ylim(bottom=0.7, top=1.05)
    
    plt.legend( fontsize=11)
    plt.tight_layout()
plot_SEE_rate()

plt.savefig("dielectron_yesSEE_SEErate.pdf")
# Out:
# <img src="data:image/png;base64,..." width="399.76666666666665">
# /home/tavant/Data/test_75/
# found 1250 files
# I've found a temporale file !
# found 1 files
# loading dat file
# /home/tavant/Data/test_99/
# found 1251 files
# I've found a temporale file !
# found 1 files
# loading dat file
# /home/tavant/these/code/venv/stand/lib64/python3.7/site-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in true_divide
#   from ipykernel import kernelapp as app
# /home/tavant/these/code/venv/stand/lib64/python3.7/site-packages/ipykernel_launcher.py:26: UserWarning: This figure was using constrained_layout==True, but that is incompatible with subplots_adjust and or tight_layout: setting constrained_layout==False.

# %% [markdown]
# # Sheath and SEE

# %%
def get_2Dcut(path):
    F = field(path)
    Er = F.return_cut2d("Ej(2)", "x", 0.5)
    return Er

def get_radial_evol(path, pos=0):
    F = field(path)
    Er = F.return_cut2d("Ej(2)", "y", pos)
    return Er

def print_2Dcut(Er, path, case=1):
    F = field(path)
    
    
    plt.figure(figsize=(3, 3))
    F.definecoords()
    
    y_lim = F._nT*F._dT*F._Na*1e6
    if case == 1:
        x_lim = F._Ly*100
        vlim = np.abs(Er).max()
        vmin = -vlim
        vmax = vlim
        cmap = "seismic"
    elif case==2:
        x_lim = F._Lx*100
        vmin = 0.9*Er.min()
        vmax = Er.max()
        cmap = "Purples_r"
        
    plt.imshow(Er*1e-3, cmap=cmap, vmin=vmin*1e-3, vmax=vmax*1e-3, extent=(0, x_lim, 0, y_lim),
              )
    
    if case==1:
        plt.xlabel("Radial position [cm]", fontsize=12)
        
    elif case==2:
        plt.xlabel("Azimuthal position [cm]", fontsize=12)
    
    
    plt.ylabel("Time [$\\mu$s]", fontsize=12)
    cb = plt.colorbar()
    
    #cb.ax.set_ylabel("$E_r$ [kV/m]", fontsize=12)
    plt.text(0.3, 10.5, "$E_r$ [kV/m]", fontsize=12, )

    #plt.text(0.25, -0.05, "Radial position [cm]", fontsize=12, )
    return plt.gca()

# %%
F._ymax*0.002
# Out:
# 2.0

# %%
Er_diel_azimuthal = get_radial_evol(paths[1], pos=0.001)
Er_nodiel_azimuthal = get_radial_evol(paths[2], pos=0.001)
# Out:
# found 1251 files
#  1250  over  1251251 1251found 1250 files
#  1249  over  1250250

# %%
Er_diel_azimuthaltmp = Er_diel_azimuthal.copy()
#Er_diel_azimuthaltmp[Er_diel_azimuthaltmp < -700e3] = -700e3
#Er_diel_azimuthaltmp[Er_diel_azimuthaltmp > 100e3] = 100e3

ax = print_2Dcut(Er_diel_azimuthaltmp, paths[1], case=2)

plt.savefig("ch3_Diel_2dcut_azimuthal.png", dpi=300)

#Er_nodiel_azimuthaltmp = Er_nodiel_azimuthal.copy()
#Er_nodiel_azimuthaltmp[Er_nodiel_azimuthaltmp < -900e3] = -900e3
#Er_diel_azimuthaltmp[Er_diel_azimuthaltmp > 100e3] = 100e3

ax = print_2Dcut(Er_nodiel_azimuthal, paths[2], case=2)

plt.savefig("ch3_noDiel_2dcut_azimuthal.png", dpi=300, bbox_inches="tight")
# Out:
# found 1251 files
# found 1250 files

# %%
<div class="cite2c-biblio"></div><div class="cite2c-biblio"></div>

# %%
Er_nodiel = get_2Dcut(paths[2])
print_2Dcut(Er_nodiel, paths[2])

# %%
#Er_nodiel = get_2Dcut(paths[2])
#ax = print_2Dcut(np.r_[Er_nodiel[:, 0:100].T,Er_nodiel[:, -100:-1].T].T, paths[2])
#ax.axvspan(0.9,1.1, facecolor="w")


F = field(paths[2])

f,(ax,ax2) = plt.subplots(1,2,sharey=True, facecolor='w',
                          figsize=(3,3),
                          gridspec_kw={"wspace":0.1, "bottom":0.5})
vlim = np.abs(Er_nodiel).max()
vmin = -vlim
vmax = vlim
x_lim = F._Ly*100
y_lim = F._nT*F._dT*F._Na*1e6
# plot the same data on both axes
im=ax.imshow(Er_nodiel*1e-3, cmap="seismic", vmin=vmin*1e-3, vmax=vmax*1e-3, extent=(0, x_lim, 0, y_lim))
im2=ax2.imshow(Er_nodiel*1e-3, cmap="seismic", vmin=vmin*1e-3, vmax=vmax*1e-3, extent=(0, x_lim, 0, y_lim))

ax.set_xlim(0,0.19)
ax2.set_xlim(1.81,2)

# hide the spines between ax and ax2
ax.spines['right'].set_visible(False)
ax2.spines['left'].set_visible(False)
ax.yaxis.tick_left()
#ax.tick_params(labelright='off')
ax2.tick_params(labelleft='off')

ax2.yaxis.tick_right()

ax.set_ylabel("Time [$\\mu$s]", fontsize=12)

axbig = f.add_subplot(111, facecolor="None")
#axbig.set_axis_off()

axbig.get_xaxis().set_visible(False)
axbig.get_yaxis().set_visible(False)

axbig.spines['top'].set_color('none')
axbig.spines['bottom'].set_color('none')
axbig.spines['left'].set_color('none')
axbig.spines['right'].set_color('none')

axbig.set_xlabel("Radial position [cm]", fontsize=12)
axbig.grid()


d = .03 # how big to make the diagonal lines in axes coordinates
# arguments to pass plot, just so we don't keep repeating them
kwargs = dict(transform=ax.transAxes, color='k', clip_on=False, linewidth=1)
ax.plot((1-d,1+d), (-d,+d), **kwargs)
ax.plot((1-d,1+d),(1-d,1+d), **kwargs)

kwargs.update(transform=ax2.transAxes)  # switch to the bottom axes
ax2.plot((-d,+d), (1-d,1+d), **kwargs)
ax2.plot((-d,+d), (-d,+d), **kwargs)

cb = f.colorbar(im2, ax=ax2)


#cb.ax.set_ylabel("$E_r$ [kV/m]", fontsize=12)
ax.text(0,-1.5," ")
plt.text(1, 1.4, "$E_r$ [kV/m]", fontsize=12, )

plt.text(0.25, -0.05, "Radial position [cm]", fontsize=12, )
plt.savefig("Er_2dcut_noDiel_RSO.png", dpi=300, bbox_inches="tight")
# Out:
# found 1250 files

# %%
Er_diel = get_2Dcut(paths[1])
print_2Dcut(Er_diel, paths[1])
# Out:
# found 1251 files
#  1250  over  1251over  1251 1251 1251found 1251 files

# %%
#Er_nodiel = get_2Dcut(paths[2])
#ax = print_2Dcut(np.r_[Er_nodiel[:, 0:100].T,Er_nodiel[:, -100:-1].T].T, paths[2])
#ax.axvspan(0.9,1.1, facecolor="w")



F = field(paths[1])

f,(ax,ax2) = plt.subplots(1,2,sharey=True, facecolor='w',
                          figsize=(3,3),
                          gridspec_kw={"wspace":0.1, "bottom":0.5})
vlim = np.abs(Er_diel).max()
vmin = -vlim
vmax = vlim
x_lim = F._Ly*100
y_lim = F._nT*F._dT*F._Na*1e6
# plot the same data on both axes
im=ax.imshow(Er_diel*1e-3, cmap="seismic", vmin=vmin*1e-3, vmax=vmax*1e-3, extent=(0, x_lim, 0, y_lim))
im2=ax2.imshow(Er_diel*1e-3, cmap="seismic", vmin=vmin*1e-3, vmax=vmax*1e-3, extent=(0, x_lim, 0, y_lim))

ax.set_xlim(0,0.19)
ax2.set_xlim(1.81,2)

# hide the spines between ax and ax2
ax.spines['right'].set_visible(False)
ax2.spines['left'].set_visible(False)
ax.yaxis.tick_left()
#ax.tick_params(labelright='off')
ax2.tick_params(labelleft='off')

ax2.yaxis.tick_right()

ax.set_ylabel("Time [$\\mu$s]", fontsize=12)

axbig = f.add_subplot(111, facecolor="None")
#axbig.set_axis_off()

axbig.get_xaxis().set_visible(False)
axbig.get_yaxis().set_visible(False)

axbig.spines['top'].set_color('none')
axbig.spines['bottom'].set_color('none')
axbig.spines['left'].set_color('none')
axbig.spines['right'].set_color('none')

axbig.set_xlabel("Radial position [cm]", fontsize=12)
axbig.grid()


d = .03 # how big to make the diagonal lines in axes coordinates
# arguments to pass plot, just so we don't keep repeating them
kwargs = dict(transform=ax.transAxes, color='k', clip_on=False, linewidth=1)
ax.plot((1-d,1+d), (-d,+d), **kwargs)
ax.plot((1-d,1+d),(1-d,1+d), **kwargs)

kwargs.update(transform=ax2.transAxes)  # switch to the bottom axes
ax2.plot((-d,+d), (1-d,1+d), **kwargs)
ax2.plot((-d,+d), (-d,+d), **kwargs)

cb = f.colorbar(im2, ax=ax2)


#cb.ax.set_ylabel("$E_r$ [kV/m]", fontsize=12)

ax.text(0,-1.5," ")
plt.text(1, 1.4, "$E_r$ [kV/m]", fontsize=12, )

plt.text(0.25, -0.05, "Radial position [cm]", fontsize=12, )

plt.savefig("Er_2dcut_Diel_RSO.png", dpi=300, bbox_inches="tight")
# Out:
# found 1251 files

# %%
plt.figure(figsize=(4,3))

F = field(paths[2])
F.definecoords()
plt.plot(F.tab_time, Er_nodiel[:, 0]*1e-3, label="Upper")
plt.plot(F.tab_time, -Er_nodiel[:, -1]*1e-3, label="Lower")

plt.legend()
plt.ylabel("Radial electric field $E_R$ [kV/m]", fontsize=12)
plt.xlabel("Time [$\\mu$s]", fontsize=12)
# Out:
# <img src="data:image/png;base64,..." width="399.76666666666665">
# found 1250 files
# Text(0.5, 0, 'Time [$\\mu$s]')

# %%
plt.figure(figsize=(4,3))

F = field(paths[1])
F.definecoords()

plt.plot(F.tab_time, Er_diel[:, 0]*1e-3, label="r=0 cm")
plt.plot(F.tab_time, -Er_diel[:, -1]*1e-3, label="r=2 cm")

plt.legend()
plt.ylabel("Radial electric field $E_R$ [kV/m]", fontsize=12)
plt.xlabel("Time [$\\mu$s]", fontsize=12)

plt.ylim(-100, 500)
plt.xlim(0,10)
plt.savefig("ch3_two_walls_comp.pdf")
# Out:
# <img src="data:image/png;base64,..." width="399.76666666666665">
# found 1251 files

# %%
Er_diel_azimuthal = get_radial_evol(paths[1])
Er_diel_azimuthal_d = get_radial_evol(paths[1], pos=1)
# Out:
# found 1251 files
#  1250  over  1251 1251found 1251 files
#  1250  over  1251

# %%
ax = print_2Dcut(Er_diel_azimuthal[:, 1:-1 ], paths[1], case=2)
plt.savefig("ch3_noDiel_2dcut_azimuthal.png", dpi=300)
# Out:
# found 1251 files
# <img src="data:image/png;base64,..." width="399.76666666666665">

# %%
ax = print_2Dcut(-Er_diel_azimuthal_d[:, 1:-1 ], paths[1], case=2)
plt.savefig("ch3_noDiel_2dcut_azimuthal_down.png", dpi=300)
# Out:
# found 1251 files
# <img src="data:image/png;base64,..." width="399.76666666666665">

# %% [markdown]
# ## Surface charge Vs $E_R$

# %%
w = Walls(paths[1])
simg_vector_0 = np.zeros(w._nT)
simg_vector_1 = np.zeros(w._nT)
print(w._files[0])
for i in range( w._nT):
    tab = w.return_fromkey(i, "Surface charge")
    simg_vector_0[i] = tab[0, 127]
    simg_vector_1[i] = tab[1, 127]
# Out:
# found 1250 files
# /home/tavant/Data/test_99/data/walls360loop0000002000.h5

# %%
plt.figure(figsize=(7,3.5))

F = field(paths[1])
F.definecoords()


tab=Er_diel[:, 0]*1e-3

plt.subplot(121)
alpha=0.8
ld=1.7
l1, = plt.plot(F.tab_time, tab, label="$E_R$", alpha=alpha, linewidth=ld)

l2, = plt.plot(F.tab_time[1:], simg_vector_0/simg_vector_0.min()*tab.max(), label="Surface charge", alpha=alpha, linewidth=ld)


plt.ylabel("Electric field [kV/m]", fontsize=11)
plt.xlabel("Time [$\\mu$s]", fontsize=11)
plt.ylim(bottom=-300, top=500)
#plt.legend()
plt.xlim(0,10)
#plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.2),
#          ncol=2, fontsize=12)
           
plt.text(0.3, -250, "a", fontsize=13)
plt.subplot(122)

tab=-Er_diel[:, -1]*1e-3
plt.plot(F.tab_time, tab, label="$E_R$", alpha=alpha, linewidth=ld)
plt.plot(F.tab_time[1:], 1.2*simg_vector_1/simg_vector_1.min()*tab.max(), label="Surface charge", alpha=alpha, linewidth=ld)

plt.xlabel("Time [$\\mu$s]", fontsize=11)
plt.ylim(bottom=-300, top=500)

plt.xlim(0,10)

plt.tight_layout(rect=(0.01, 0.01, 0.99, 0.9))

plt.figlegend([l1, l2], ["$E_R$", "Surface charge"], loc='upper center', bbox_to_anchor=(0.5, 0.95),
          ncol=2, fontsize=11)

plt.text(0.3, -250, "b", fontsize=13)

plt.savefig("ch3_Er_vs_sigma_diel.png", dpi=400)
# Out:
# found 1251 files
# /home/tavant/these/code/venv/stand/lib64/python3.7/site-packages/ipykernel_launcher.py:37: UserWarning: This figure was using constrained_layout==True, but that is incompatible with subplots_adjust and or tight_layout: setting constrained_layout==False.

# %%
plt.figure()
plt.plot(F.tab_time[1:], simg_vector_1/simg_vector_1.min(), label="Surface charge")

tab=-Er_diel[:, -1]
plt.plot(F.tab_time, tab/tab.max(), label="$E_R$")

plt.ylabel("Normalized")
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="399.76666666666665">

# %%
w = Walls(paths[2])
simg_vector_0_nodiel = np.zeros(w._nT)
simg_vector_1_nodiel = np.zeros(w._nT)
print(w._files[0])
for i in range( w._nT):
    tab = w.return_fromkey(i, "Surface charge")
    simg_vector_0_nodiel[i] = tab[0, 127]
    simg_vector_1_nodiel[i] = tab[1, 127]
    
   

plt.figure()
plt.plot(F.tab_time, simg_vector_0_nodiel/simg_vector_0_nodiel.min(), label="Surface charge")

tab=Er_diel[:, 0]
plt.plot(F.tab_time, tab[1:]/tab[1:].max(), label="$E_R$")

plt.ylabel("Normalized")
plt.legend()
# Out:
# found 1250 files
# /home/tavant/Data/test_75/data/walls360loop0000002000.h5

# %%
plt.figure()
F = field(paths[2])
F.definecoords()
vect = simg_vector_0_nodiel #np.cumsum(simg_vector_0_nodiel)
plt.plot(F.tab_time, vect/vect.min(), label="Surface charge")

tab=Er_nodiel[:, 0]
plt.plot(F.tab_time, tab/tab.max(), label="$E_R$")

plt.ylabel("Normalized")
plt.xlabel("Time [$\\mu$s]")
plt.ylim(top=1.3)
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="399.76666666666665">
# found 1250 files

# %%
def plot_surf_charge():
    
    plt.figure()
    
    labels = ["No dielectric", "With dielectric"]

    for i, n in zip([2, 1], labels):
        
        path=paths[i]
        print(path)
        F = field(path)
        Er = F.return_cut2d("Ej(2)", "x", 0.5)
        
        print(Er.shape)
        
        H = History(path)
        temporal_data = H.return_history()
        time = temporal_data["time"]*1e6
        rate =  (temporal_data["elec_SEE"] +  temporal_data["elec_SEE_sup"])/ temporal_data["elec_wal"]
        rate[0] = 0

        plt.plot(time, Er[F._ndiel,:], label=n)
        
    plt.xlabel("Time [$\mu$s]", fontsize=11)
    plt.ylabel("Emission rate $\\bar{\\sigma}$", fontsize=11)
    plt.xlim(left=0, right=10)
    plt.ylim(bottom=0.7, top=1.05)
    
    plt.legend( fontsize=11)
    plt.tight_layout()
plot_surf_charge()

plt.savefig("dielectron_yesSEE_charge.pdf")
# Out:
# <img src="data:image/png;base64,..." width="399.76666666666665">
# /home/tavant/Data/test_75/
# found 1250 files
#  1249  over  1250(1250, 1001)
# I've found a temporale file !
# found 1 files
# loading dat file
# /home/tavant/these/code/venv/stand/lib64/python3.7/site-packages/ipykernel_launcher.py:19: RuntimeWarning: invalid value encountered in true_divide
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-bbe595719e6d> in <module>
#      29     plt.legend( fontsize=11)
#      30     plt.tight_layout()
# ---> 31 plot_surf_charge()
#      32
#      33 plt.savefig("dielectron_yesSEE_charge.pdf")
#
# <ipython-input-16-bbe595719e6d> in plot_surf_charge()
#      20         rate[0] = 0
#      21
# ---> 22         plt.plot(time, Er[F._ndiel,:], label=n)
#      23
#      24     plt.xlabel("Time [$\mu$s]", fontsize=11)
#
# ~/these/code/venv/stand/lib64/python3.7/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2793     return gca().plot(
#    2794         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2795         is not None else {}), **kwargs)
#    2796
#    2797
#
# ~/these/code/venv/stand/lib64/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1664         """
#    1665         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1666         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1667         for line in lines:
#    1668             self.add_line(line)
#
# ~/these/code/venv/stand/lib64/python3.7/site-packages/matplotlib/axes/_base.py in __call__(self, *args, **kwargs)
#     223                 this += args[0],
#     224                 args = args[1:]
# --> 225             yield from self._plot_args(this, kwargs)
#     226
#     227     def get_next_color(self):
#
# ~/these/code/venv/stand/lib64/python3.7/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     389             x, y = index_of(tup[-1])
#     390
# --> 391         x, y = self._xy_from_xy(x, y)
#     392
#     393         if self.command == 'plot':
#
# ~/these/code/venv/stand/lib64/python3.7/site-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     268         if x.shape[0] != y.shape[0]:
#     269             raise ValueError("x and y must have same first dimension, but "
# --> 270                              "have shapes {} and {}".format(x.shape, y.shape))
#     271         if x.ndim > 2 or y.ndim > 2:
#     272             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (1251,) and (1001,)

# %% [markdown]
# # Test enuman condition

# %%
plt.figure()
  
labels = ["With dielectric"]

for i, n in zip([2], labels):
        
    path=paths[i]
    print(path)
    F = field(path)
    F.definecoords()
    tab = F.return_fromkey(-1, "Ej(2)")
    plt.plot(F.tab_x, tab[:, 0]*1e-3, label="$E_R$")
    
    W = Walls(path)
    hdf_key='Surface charge'

    tab = W.return_fromkey(-1, hdf_key)
    var = tab*W._qf*W.qe/(W._dX*W.eps0)
    
    plt.plot(F.tab_x, var[0]*1e-6, label="$\\sigma/\\epsilon_0$")
    
        
plt.xlabel("Aximuthal_position [cm]", fontsize=11)
plt.ylabel("Electric field [kV/m]", fontsize=11)
#plt.xlim(left=0, right=10)
#plt.ylim(bottom=0.7, top=1.05)

plt.legend( fontsize=11)
plt.tight_layout()


plt.savefig("dielectron_neuman_azimuthal.pdf")
# Out:
# <img src="data:image/png;base64,..." width="400">
# /home/tavant/Data/test_75/
# found 1250 files
# found 1250 files

# %%
plt.figure()
  
i=2
        
path=paths[i]
print(path)
F = field(path)
F.definecoords()

E_r = np.zeros(F._nT)

# for j in range(F._nT):
#     E_r[j] =  F.return_fromkey(j, "Ej(2)")[2, 0]
    
# plt.plot(F.tab_time, E_r*1e-3, label="$E_R$")
 
W = Walls(path)
W.definecoords()
hdf_key='Surface charge'
hdf_key='Elec_pos'
hdf_key='Ions_pos'

E_r = np.zeros(W._nT)
for j in range(W._nT):
    tab = W.return_fromkey(j, 'Ions_pos') + W.return_fromkey(j, 'Elec_pos')
    var = tab*W._qf*W.qe/(W._dX*W.eps0)
    E_r[j] = var[1, 2]

plt.plot(W.tab_time, E_r*1e-6, label="$\\sigma/\\epsilon_0$")
    
for j in range(W._nT):

    tab = W.return_fromkey(j, 'Surface charge')
    var = tab*W._qf*W.qe/(W._dX*W.eps0)
    E_r[j] = var[1, 2]

plt.plot(W.tab_time, E_r*1e-6, label="$\\sigma/\\epsilon_0$")
          
plt.xlabel("Time  [$\\mu$s]", fontsize=11)
plt.ylabel("Electric field [kV/m]", fontsize=11)
plt.xlim(left=0, right=10)
#plt.ylim(bottom=0.7, top=1.05)

plt.legend( fontsize=11)
plt.tight_layout()


plt.savefig("dielectron_neuman_time.pdf")
# Out:
# <img src="data:image/png;base64,..." width="400">
# /home/tavant/Data/test_75/
# found 1250 files
# found 1250 files

# %%
def plot_SEE_profiles():
    
    plt.figure()
    
    labels = ["No dielectric", "With dielectric"]

    for i, n in zip([3, 2], labels):
        
        path=paths[i]
        print(path)
        F = field(path)
        F.definecoords()        
        H = History(path)
        temporal_data = H.return_history()
        time = temporal_data["time"]*1e6
        rate =  (temporal_data["elec_SEE"] +  temporal_data["elec_SEE_sup"])/ temporal_data["elec_wal"]
        rate[0] = 0
        
        tab_ne = F.meanfield(label="Nume", mean_axis="x", imin=0.5, keepdiel=False)

        x = np.linspace(0, F._Ly, len(tab_ne))
        plt.plot(x, tab_ne, label=n)
        
    plt.xlabel("Radial position [cm]", fontsize=11)
    plt.ylabel("Electron density $n_e$ [m$^{-3}$]", fontsize=11)
    
    plt.legend( fontsize=11)
    plt.tight_layout()
    
plot_SEE_profiles()

plt.savefig("dielectron_yesSEE_profile_ne.pdf")
# Out:
# <img src="data:image/png;base64,..." width="400">
# /home/tavant/Data/test_75/
# found 1250 files
# I've found a temporale file !
# found 1 files
# loading dat file
# /home/tavant/Data/test_99/
# found 1251 files
# I've found a temporale file !
# found 1 files
# loading dat file
# 1251
# calculating the mean between 5.00$ \mu s$  and 10.01$ \mu s$
# /home/tavant/these/code/venv/stand/lib64/python3.7/site-packages/ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in true_divide

# %%
def plot_SEE_profiles_mu():
    
    plt.figure()
    
    labels = ["No dielectric", "With dielectric"]

    for i, n in zip([3, 2], labels):
        
        path=paths[i]
        print(path)
        F = field(path)
        F.definecoords()        
        H = History(path)
        temporal_data = H.return_history()
        time = temporal_data["time"]*1e6
        rate =  (temporal_data["elec_SEE"] +  temporal_data["elec_SEE_sup"])/ temporal_data["elec_wal"]
        rate[0] = 0
        
        tab_ne = F.meanfield(label="Mob", mean_axis="x", imin=0.5, keepdiel=False)

        x = np.linspace(0, F._Ly, len(tab_ne))
        plt.plot(x, tab_ne, label=n)
        
    plt.xlabel("Radial position [cm]", fontsize=11)
    plt.ylabel("Electron mobility $\mu_{\\rm PIC}$ [m$^2$ (s V)$^{-1}$]", fontsize=11)
    
    plt.legend( fontsize=11)
    plt.tight_layout()
    
plot_SEE_profiles_mu()

plt.savefig("dielectron_yesSEE_profile_mu.pdf")
# Out:
# <img src="data:image/png;base64,..." width="400">
# /home/tavant/Data/test_75/
# found 1250 files
# I've found a temporale file !
# found 1 files
# loading dat file
# 1250
# calculating the mean between 5.00$ \mu s$  and 10.00$ \mu s$
# /home/tavant/these/code/venv/stand/lib64/python3.7/site-packages/ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in true_divide
# /home/tavant/Data/test_99/
# found 1251 files
# I've found a temporale file !
# found 1 files
# loading dat file
# 1251
# calculating the mean between 5.00$ \mu s$  and 10.01$ \mu s$

# %%
def plot_SEE_profiles():
    
    plt.figure()
    
    labels = ["No dielectric", "With dielectric"]

    for i, n in zip([3, 2], labels):
        
        path=paths[i]
        print(path)
        F = field(path)
        F.definecoords()        
        H = History(path)
        temporal_data = H.return_history()
        time = temporal_data["time"]*1e6
        rate =  (temporal_data["elec_SEE"] +  temporal_data["elec_SEE_sup"])/ temporal_data["elec_wal"]
        rate[0] = 0
        
        tab_ne = F.meanfield(label="Numi", mean_axis="x", imin=0.5, keepdiel=False)

        x = np.linspace(0, F._Ly, len(tab_ne))
        plt.plot(x, tab_ne, label=n)
        
    plt.xlabel("Radial position [cm]", fontsize=11)
    plt.ylabel("Ion density $n_i$ [m$^{-3}$]", fontsize=11)
    
    plt.legend( fontsize=11)
    plt.tight_layout()
    
plot_SEE_profiles()

plt.savefig("dielectron_yesSEE_profile_ni.pdf")
# Out:
# <img src="data:image/png;base64,..." width="400">
# /home/tavant/Data/test_75/
# found 1250 files
# I've found a temporale file !
# found 1 files
# loading dat file
# 1250
# calculating the mean between 5.00$ \mu s$  and 10.00$ \mu s$
# /home/tavant/these/code/venv/stand/lib64/python3.7/site-packages/ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in true_divide
# /home/tavant/Data/test_99/
# found 1251 files
# I've found a temporale file !
# found 1 files
# loading dat file
# 1251
# calculating the mean between 5.00$ \mu s$  and 10.01$ \mu s$

# %%
def plot_SEE_profiles():
    
    plt.figure()
    
    labels = ["No dielectric", "With dielectric"]

    for i, n in zip([3, 2], labels):
        
        path=paths[i]
        print(path)
        F = field(path)
        F.definecoords()        
        H = History(path)
        temporal_data = H.return_history()
        time = temporal_data["time"]*1e6
        rate =  (temporal_data["elec_SEE"] +  temporal_data["elec_SEE_sup"])/ temporal_data["elec_wal"]
        rate[0] = 0
        
        tab_ne = F.meanfield(label="Phi", mean_axis="x", imin=0.5, keepdiel=True)

        x = np.linspace(0, F._Ly, len(tab_ne))*100
        Ldiel = F.inputobject.parameters["Ldiel"]
        if i==2:
            F.definecoords()
            x = F.tab_y - Ldiel*100
            
        plt.plot(x, tab_ne, label=n)
        
    plt.xlabel("Radial position [cm]", fontsize=11)
    plt.ylabel("Plasma potential $\\phi$ [V]", fontsize=11)
    
    plt.legend( fontsize=11)
    plt.tight_layout()
    
plot_SEE_profiles()

plt.savefig("dielectron_yesSEE_profile_phi.pdf")
# Out:
# <img src="data:image/png;base64,..." width="400">
# /home/tavant/Data/test_75/
# found 1250 files
# I've found a temporale file !
# found 1 files
# loading dat file
# /home/tavant/Data/test_99/
# found 1251 files
# I've found a temporale file !
# found 1 files
# loading dat file
# /home/tavant/these/code/venv/stand/lib64/python3.7/site-packages/ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in true_divide

# %%
F.definecoords()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-109-0a54261da80e> in <module>
# ----> 1 F.definecoords()
#
# ~/these/code/LPPview/LPPview/Classes/LPPic.py in definecoords(self)
#     292         self.tab_time = np.array([((t+self._No)*self._Na*self._dT)*1e6 for t in np.arange(self._nT)])
#     293
# --> 294         taby = np.loadtxt(self._data_path + "tab_dy.txt")
#     295
#     296         self.tab_y = [0 for i in taby]
#
# ~/these/code/venv/stand/lib64/python3.7/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#     960             fname = os_fspath(fname)
#     961         if _is_string_like(fname):
# --> 962             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     963             fencoding = getattr(fh, 'encoding', 'latin1')
#     964             fh = iter(fh)
#
# ~/these/code/venv/stand/lib64/python3.7/site-packages/numpy/lib/_datasource.py in open(path, mode, destpath, encoding, newline)
#     264
#     265     ds = DataSource(destpath)
# --> 266     return ds.open(path, mode, encoding=encoding, newline=newline)
#     267
#     268
#
# ~/these/code/venv/stand/lib64/python3.7/site-packages/numpy/lib/_datasource.py in open(self, path, mode, encoding, newline)
#     622                                       encoding=encoding, newline=newline)
#     623         else:
# --> 624             raise IOError("%s not found." % path)
#     625
#     626
#
# OSError: /home/tavant/Data/test_65/data/tab_dy.txt not found.

# %% [markdown]
# <cite data-cite="4025345/8CGS7RDB"></cite>

# %% [markdown]
# <div class="cite2c-biblio"></div>

# %% [markdown]
# <div class="cite2c-biblio"></div>
